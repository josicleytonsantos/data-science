# %% [markdown]
# Aula 01 - Introdução ao Python:
#
# Aula 1 - Introdução ao Python: I/O, tipos de dados, operações, estruturas de decisão e de repetição, e estruturas de dados
#
# Aula 2 - Referências, funções, funções avançadas, list comprehension, noções básicas de POO
#
# Aula 3 - Numpy I: array, slicing, fancy index, copy and view
#
# Aula 4 - Pandas I: dataframes, series, index, Pandas I/O (csv, json, excel)
#
# Aula 5 (30/09) - Matplotlib I: construção de gráficos usuais
#
# Aula 6 (07/10) - Matplotlib II e Numpy II: operações com array, broadcasting, Pandas II: limpeza de dados e estatísticas básicas
#
# Aula 7 (14/10) - SciKit Learn: classificação e regressão básicos
#
# Aula 8 (21/10) - Web Scraping + Kaggle + fontes de datasets
#
# Aula 9 (28/10) - Projeto Final

# %% [markdown]
# ### 📊 O que é Ciência de Dados?
#
# A **Ciência de Dados** é uma área interdisciplinar que combina:
#
# - Ciência da Computação
# - Matemática
# - Estatística
#
# Seu principal objetivo é **extrair conhecimento e gerar insights a partir de dados**.
#
# ### 🔄 Ciclo de Vida de um Projeto de Dados
#
# #### 1. Coleta de Dados (Data Collection)
# Coleta de dados a partir de diferentes fontes.
#
# #### 2. Preparação dos Dados (Data Preparation)
# Tratamento e organização dos dados para análise.
#
# #### 3. Exploração e Visualização
# Análise exploratória para entender padrões e comportamentos nos dados.
#
# #### 4. Experimentação e Predição
# Criação de modelos, análises ou experimentos para gerar previsões ou respostas.
#
# #### 5. Comunicação de Resultados (Data Storytelling)
# Compartilhamento de insights de forma clara e eficaz.
#
# ### 🐍 Por que Python?
#
# #### ✔️ Simplicidade
# - Linguagem de alto nível
# - Foco em legibilidade e facilidade de escrita
#
# #### 📚 Vasta gama de bibliotecas
#
# - **Pandas** → Manipulação e análise de dados tabulares
# - **NumPy** → Computação numérica e operações com matrizes
# - **Matplotlib** → Criação de gráficos e visualizações
# - **TensorFlow / PyTorch / Scikit-learn** → Machine Learning e Redes Neurais

# %% [markdown]
# ---

# %% [markdown]
# ### 📦 Variáveis em Python
#
# #### 📌 O que são variáveis?
#
# Variáveis são utilizadas para **armazenar informações na memória**.
#
# - Cada variável armazena um valor
# - Esse valor possui um **tipo de dado**
#
# #### 🔢 Tipos de dados básicos
#
# Alguns dos principais tipos em Python:
#
# - `int` → números inteiros
# - `float` → números decimais
# - `str` → textos (strings)
# - `bool` → valores lógicos (`True` ou `False`)
# - `None` → ausência de valor
#
# #### 🤖 Tipagem em Python
#
# Python é uma linguagem de **tipagem dinâmica**, ou seja:
#
# - Você **não precisa declarar o tipo** da variável
# - O próprio Python **identifica automaticamente** o tipo com base no valor

# %%
idade = 25        # int
altura = 1.75     # float
nome = "Maria"    # str
ativo = True      # bool

# %%
idade: int = "vinte e cinco"  # Python permite, mas está errado conceitualmente

# %% [markdown]
# ---

# %% [markdown]
# ### 🔄 Input e Output (I/O)
#
# #### 📥 Input (Entrada)
# É a forma de **ler dados do usuário**.
#
# - Em Python, utilizamos a função `input()`
#
# ```bash
# nome = input("Digite seu nome: ")
# print(nome)
# ```
#
# 📌 Importante:
# - O valor retornado pelo input() sempre será do tipo str (string)
#
# #### 📤 Output (Saída)
#
# É a forma de mostrar informações para o usuário.
#
# Utilizamos a função `print()`

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# #### 🧾 Quebra de linha no `print`
# Por padrão, o `print()` adiciona uma quebra de linha (\n) ao final.

# %%
print("Linha 1")
print("Linha 2")
# Out:
# Linha 1
# Linha 2

# %% [markdown]
# #### 🔢 Convertendo tipos de entrada
# Como o `input()` sempre retorna uma string, muitas vezes precisamos converter o valor:
#
# ```bash
# idade = int(input("Digite sua idade: "))
# print(idade)
# ```

# %% [markdown]
# ---

# %% [markdown]
# ### 🔀 Estruturas de Decisão
#
# As **estruturas de decisão** permitem que o código **execute ações diferentes dependendo de uma condição**.
#
# 👉 Ou seja: um bloco de código **só será executado se uma condição for verdadeira**.
#
# ⚠️ Importante
# - As condições devem resultar em True ou False
# - A indentação define o que pertence a cada bloco
# - Apenas o primeiro bloco verdadeiro será executado

# %%
x = 10

if (x > 10):
    print("X maior que 10")
else:
    print("X menor ou igual a 10")
print("Essa mensagem não depende de x") # importância da indentação
# Out:
# X menor ou igual a 10
# Essa mensagem não depende de x

# %% [markdown]
# ### 🔀 Usando elif (senão se)

# %%
nota = 7

if nota >= 9:
    print("Excelente")
elif nota >= 6:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Aprovado

# %% [markdown]
# ### ⚙️ Operadores Importantes em Estruturas de Decisão
#
# #### 📖 Explicação
#
# Os operadores são símbolos ou palavras que permitem comparar valores e combinar condições dentro das estruturas de decisão.
#
# ---
#
# #### 🔎 Operadores de comparação
#
# Eles comparam dois valores e retornam `True` ou `False`:
#
# | Operador | Descrição                | Exemplo           | Resultado                        |
# |----------|-------------------------|-------------------|---------------------------------|
# | `==`     | Igual a                 | `x == 10`         | `True` se x for 10              |
# | `!=`     | Diferente de            | `x != 5`          | `True` se x não for 5           |
# | `>`      | Maior que               | `x > 3`           | `True` se x for maior que 3     |
# | `<`      | Menor que               | `x < 8`           | `True` se x for menor que 8     |
# | `>=`     | Maior ou igual a        | `x >= 7`          | `True` se x for 7 ou mais       |
# | `<=`     | Menor ou igual a        | `x <= 4`          | `True` se x for 4 ou menos      |
#
# ---
#
# #### 🔗 Operadores lógicos
#
# Usados para combinar múltiplas condições:
#
# | Operador | Descrição               | Exemplo               | Resultado                                                        |
# |----------|------------------------|-----------------------|-----------------------------------------------------------------|
# | `and`    | E (todas verdadeiras)  | `(x > 5) and (x < 10)`| `True` se ambas as condições forem verdadeiras                  |
# | `or`     | Ou (pelo menos uma verdadeira) | `(x < 3) or (x > 7)`    | `True` se uma ou outra condição for verdadeira                  |
# | `not`    | Negação                | `not(x == 5)`         | Inverte o valor lógico (`True` vira `False` e vice-versa)       |

# %%
x = 7

# Comparação simples
if x == 7:
    print("x é igual a 7")

# Usando 'and'
if x > 5 and x < 10:
    print("x está entre 6 e 9")

# Usando 'or'
if x < 3 or x > 5:
    print("x é menor que 3 ou maior que 5")

# Usando 'not'
if not x == 5:
    print("x não é 5")
# Out:
# x é igual a 7
# x está entre 6 e 9
# x é menor que 3 ou maior que 5
# x não é 5
